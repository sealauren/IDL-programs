# %%
#%matplotlib osx
import os
os.chdir('/Users/lweiss/mrf')
# %pylab inline
import numpy as np
import math
import string
#import astroypy
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("all_exos_errors7.csv",skiprows=[1])
df.sort(inplace=True)
df.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 43 columns):
# NAME            5  non-null values
# MASS            5  non-null values
# MASSUPPER       5  non-null values
# MASSLOWER       5  non-null values
# UMASS           5  non-null values
# R               5  non-null values
# RUPPER          5  non-null values
# RLOWER          5  non-null values
# UR              5  non-null values
# DENSITY         5  non-null values
# DENSITYUPPER    5  non-null values
# DENSITYLOWER    5  non-null values
# UDENSITY        5  non-null values
# A               5  non-null values
# AUPPER          5  non-null values
# ALOWER          5  non-null values
# UA              5  non-null values
# PER             5  non-null values
# ECC             5  non-null values
# MSTAR           5  non-null values
# MSTARUPPER      5  non-null values
# MSTARLOWER      5  non-null values
# UMSTAR          5  non-null values
# RSTAR           5  non-null values
# RSTARUPPER      5  non-null values
# RSTARLOWER      5  non-null values
# URSTAR          5  non-null values
# RHOSTAR         3  non-null values
# TEFF            5  non-null values
# TEFFUPPER       5  non-null values
# TEFFLOWER       5  non-null values
# UTEFF           5  non-null values
# LOGG            5  non-null values
# FE              5  non-null values
# FEUPPER         5  non-null values
# FELOWER         5  non-null values
# UFE             5  non-null values
# VSINI           5  non-null values
# SHK             1  non-null values
# ORBREF          5  non-null values
# ORBURL          5  non-null values
# FIRSTREF        5  non-null values
# FIRSTURL        5  non-null values
# dtypes: float64(38), object(5)

# %%
new_columns = [c.lower() for c in df.columns]
df.columns = new_columns
print df.columns
# Out:
# Index([u'name', u'mass', u'massupper', u'masslower', u'umass', u'r', u'rupper', u'rlower', u'ur', u'density', u'densityupper', u'densitylower', u'udensity', u'a', u'aupper', u'alower', u'ua', u'per', u'ecc', u'mstar', u'mstarupper', u'mstarlower', u'umstar', u'rstar', u'rstarupper', u'rstarlower', u'urstar', u'rhostar', u'teff', u'teffupper', u'tefflower', u'uteff', u'logg', u'fe', u'feupper', u'felower', u'ufe', u'vsini', u'shk', u'orbref', u'orburl', u'firstref', u'firsturl'], dtype=object)

# %%
df['m'] = df.mass
df['um'] = df.umass
df['rho'] = df.density
df['urho'] = df.udensity
df.columns
# Out:
# Index([u'name', u'mass', u'massupper', u'masslower', u'umass', u'r', u'rupper', u'rlower', u'ur', u'density', u'densityupper', u'densitylower', u'udensity', u'a', u'aupper', u'alower', u'ua', u'per', u'ecc', u'mstar', u'mstarupper', u'mstarlower', u'umstar', u'rstar', u'rstarupper', u'rstarlower', u'urstar', u'rhostar', u'teff', u'teffupper', u'tefflower', u'uteff', u'logg', u'fe', u'feupper', u'felower', u'ufe', u'vsini', u'shk', u'orbref', u'orburl', u'firstref', u'firsturl', u'm', u'um', u'rho', u'urho'], dtype=object)

# %%
# Need to build local lookup table, or use wolfram_lookup, to get common values
#%load 'astrophysical_constants.txt'

# %%
mearth = 5.9721986E27 #grams
rearth = 6.3675E8 #centimeters
msun = 1.988435E33 #grams
rsun = 6.955E10 #centimeters
cmperau=1.496E13
lsun = 3.846E33 #ergs per second
tsun = 5780 #kelvins

# %%
#df['rho']= df.m*mearth/(4/3*np.pi*(df.r*rearth)**3) # cgs
#df['urho'] = np.sqrt((df.umsini/df.m)**2. + (3*df.ur/df.r)**2.)*df.rho

# %% [markdown]
# Load planets from Geoff's paper and merge the planetary and stellar tables.

# %%
df22 = pd.read_csv('h22_orbital_pars_annotated.txt',skiprows=[1],skipinitialspace=True)
df22_stars = pd.read_csv('h22_star_prop.txt',skipinitialspace=True)
df22.columns = [c.strip() for c in df22.columns]
new_columns = [c.lower() for c in df22.columns]
df22.columns = new_columns
df22.columns = ['name','per','r','ur','m','um','rho','urho','k','uk','rhostar','urhostar','b','ub','rprs','tt','mupper']
df22_stars.koi_star = [koi.strip().lstrip('k0') for koi in df22_stars.koi_star]
df22_stars
df22_stars['fe'] = df22_stars.feh
df22_stars['ufe'] = df22_stars.ufeh
df22['koi_star']=[k.strip()[:-3] for k in df22.name]
df22_full = pd.merge(df22,df22_stars)
df22_full['name'] = ["KOI-"+koi for koi in df22_full.name]
df22_full.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 37 columns):
# name        5  non-null values
# per         5  non-null values
# r           5  non-null values
# ur          5  non-null values
# m           5  non-null values
# um          5  non-null values
# rho         5  non-null values
# urho        5  non-null values
# k           5  non-null values
# uk          5  non-null values
# rhostar     5  non-null values
# urhostar    5  non-null values
# b           5  non-null values
# ub          5  non-null values
# rprs        5  non-null values
# tt          5  non-null values
# mupper      5  non-null values
# koi_star    5  non-null values
# kid         5  non-null values
# ra          5  non-null values
# dec         5  non-null values
# teff        5  non-null values
# uteff       5  non-null values
# logg        5  non-null values
# ulogg       5  non-null values
# feh         5  non-null values
# ufeh        5  non-null values
# mstar       5  non-null values
# umstar      5  non-null values
# rstar       5  non-null values
# urstar      5  non-null values
# vsini       5  non-null values
# vmag        5  non-null values
# age         5  non-null values
# source      5  non-null values
# fe          5  non-null values
# ufe         5  non-null values
# dtypes: float64(29), int64(3), object(5)

# %% [markdown]
# Use Kepler's Law to get semi-major axis H22 planets and merge.

# %%
df22_full['a'] = pow(pow(df22_full.per/365.25,2.) * df22_full.mstar , 1/3.)
df22_full['ecc'] = [0.0] * len(df22_full)
df22_full['orbref'] = "Marcy 2013"
df22_full['firstref'] = "Borucki 2011"
df = df.append(df22_full)
df['name'] = [n.rstrip() for n in df.name]

# %% [markdown]
# Add Kepler-78 and KOI-94.

# %%
K78data = [{'name':'Kepler-78 b','m': 1.69, 'um': 0.41, 'r':1.20, 'ur':0.09, 'rho':5.3, 'urho':1.8, 
           'per':8.5/24.,'a':3.0*0.74*rsun/cmperau,'ua':.75*0.74*rsun/cmperau,'ecc':0.0,
           'mstar':0.81, 'umstar':0.05, 'rstar':0.74, 'urstar':0.09, 'teff':5089, 'uteff':50,
           'firstref':"Sanchis-Ojeda 2013", 'orbref':"Sanchis-Ojeda (2013)"
           }]
KOI94data = {'name':['KOI-94 b', 'KOI-94 c', 'KOI-94 d', 'KOI-94 e'],
             'm': [10.5, 15.6, 106., 35.], 
             'um': [4.6, 10.6, 11, 23.], 
             'r':[1.71, 4.32, 11.27, 6.56], 
             'ur':[0.16, 0.41, 1.06, 0.62], 
             'rho':[10.1, 0.91, 0.363, 0.60], 
             'urhoupper':[5.5, 0.36, 0.101, 0.26], 
             'urholower':[5.5, 0.91, 0.101, 0.56], 
            'urho':[5.5, 0.64, 0.101, 0.41], 
           'per':[3.743208, 10.423648, 22.3429890, 54.32031],
           'a':[0.05119, 0.1013, 0.1684, 0.3046],
           'ua':[0.00067, 0.0013, 0.0022, 0.0040],
           'ecc':[0.25, 0.43, 0.022, 0.019],
           'mstar':1.277, 'umstar':0.050, 'rstar':1.52, 'urstar':0.14, 
           'teff':6182, 'uteff':58, 'logg':4.181,'ulogg':0.066,
           'fe':0.0228,'ufe':0.0020, 'vsini':7.3, 'age':3.16,
           'firstref':["Borucki 2011","Borucki 2011","Borucki 2011","Batalha 2013"],
           'orbref':"Weiss 2013"
           }
KOI152data = {'name':['KOI-152 b', 'KOI-152 c', 'KOI-152 d', 'KOI-152 e'],
             'm': [10.9, 5.9, 6.0, 4.1], 
             'um': [6.7,2.1,1.85,1.15], 
             'r':[3.47,3.72,7.16,3.49], 
             'ur':[0.07,0.08,0.145,0.14], 
             'rho':[1.43,0.62,0.09,0.53], 
            'urho':[0.885,0.225,0.025,0.15], 
           'per':[13.4845,27.4029,52.0902,81.0659],
           'a':[0.117,0.187,0.287,0.386],
           'ua':[0.002,0.0025,0.004,0.005],
           'ecc':[0.015,0.030,0.025,0.012],
           'mstar':1.165, 'umstar':0.044, 'rstar':1.302, 'urstar':0.026, 
           'teff':6174, 'uteff':100, 'logg':4.274,'ulogg':0.0123,
           'age':3.44,
           'firstref':["Borucki 2011","Borucki 2011","Borucki 2011","Borucki 2013"],
           'orbref':"Lissauer 2013b"
           }
KOI314data = {'name':['KOI-314 b','KOI-314 c'],
               'm':[3.83,1.01],
               'um':[1.37,0.38],
               'r':[1.61,1.61],
               'ur':[0.16,0.16],
               'rho':[5.0,1.31],
               'urho':[2.5,0.69],
               'per':[13.78164,23.08933],
               'ecc':[0.,0.],
               'teff':3871,
               'uteff':58,
               'logg':4.73,
               'mstar':0.57, 'umstar':0.05,
               'rstar':0.54, 'urstar':0.05,
               'a':[pow(13.78164/365.24,2/3.),pow(23.08933/365.25,2/3.)],
               'firstref':["Borucki 2011","Borucki 2011"],
               'orbref':['Kipping 2014','Kipping 2014']}
K78df = pd.DataFrame(K78data)
KOI94df = pd.DataFrame(KOI94data)
KOI152df = pd.DataFrame(KOI152data)
KOI314df = pd.DataFrame(KOI314data)
df = df.append(K78df)
df = df.append(KOI94df)
df = df.append(KOI152df)
df = df.append(KOI314df)
df = df.set_index('name')

# %%
# update Ms and Rs with literature values
df.loc['55 Cnc e',['r','ur','orbref']] = [1.990, 0.084, "Endl 2012, Dragomir 2013"]
df.loc['CoRoT-7 b',['m','um','r','ur','orbref']] = [ 7.42 , 1.21 ,  1.58 , 0.1 , "Hatzes 2012"]
df.loc['GJ 1214 b',['m','um','r','ur','orbref']] = [ 6.45 , 0.91 ,  2.65 , 0.09 , "Carter 2011"]
df.loc['Kepler-10 b',['m','um','r','ur','rho','urho','mstar','umstar','rstar','urstar',
                      'teff','uteff','fe','ufe','age','orbref']] = [ 4.60, 1.26, 1.46, 0.02, 8.15, 2.26, 0.913, 0.022, 1.065, 0.009 , 
     5643, 75, -0.15, 0.07, 10.41, "Fogtmann-Shulz 2013"]
df.loc[['55 Cnc e', 'CoRoT-7 b', 'GJ 1214 b', 'KOI-94 b','Kepler-10 b'],['m','um','r','ur','mstar','rstar','ufe','orbref']]
df.loc[['Kepler-11 b','Kepler-11 c','Kepler-11 d','Kepler-11 e','Kepler-11 f'],['m','um','r','ur','rho','urho','age']] = \
[[1.9,2.9,7.3,8.0,2.0],[1.2,2.2,1.1,1.8],[1.80,2.87,3.12,4.19,2.49],[0.04,0.05,0.06,0.08,0.05],[1.72,0.66,1.28,0.58,0.69],[1.08,0.50,0.21,0.13,0.30],9.7]

# %%
df.loc[['Kepler-11 b','Kepler-11 c','Kepler-11 d','Kepler-11 e','Kepler-11 f'],['m','r','mstar','rstar']]
# Out:
#                m     r  mstar  rstar
# Kepler-11 b  1.9  1.80  0.961  1.065
# Kepler-11 c  2.9  2.87  0.961  1.065
# Kepler-11 d  7.3  3.12  0.961  1.065
# Kepler-11 e  8.0  4.19  0.961  1.100
# Kepler-11 f  2.0  2.49  0.961  1.065

# %%
# propagate Ms and Rs to new densities
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'rho'] = \
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'m']/(4/3. * pi* (df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'r'])**3.)*mearth/rearth**3.
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'urho'] = df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'rho'] * \
np.sqrt((3 * df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'ur']/df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'r'])**2. + \
        (df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'um']/df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'m'])**2.)
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],['rho','urho']]
# Out:
#                  rho      urho
# 55 Cnc e    5.872439  0.792862
# CoRoT-7 b  10.388944  2.600240
# GJ 1214 b   1.914083  0.333105

# %%
flux_earth = lsun/(4*np.pi*cmperau**2.) # flux on earth
df['flux']=df.rstar**2*(df.teff/5778.)**4/df.a**2 * np.sqrt(1./(1 - df.ecc**2))  #time avg. flux on the planet in earth fluxes
df['uflux'] = df.flux * np.sqrt((4*df.uteff/df.teff)**2. + (2*df.urstar/df.rstar)**2 + (2*df.ua/df.a)**2)
medf = np.median(df.flux)
df_hot = df[df.flux > medf]
df_cold = df[df.flux <= medf]

# %%
ss_names = {"name" : ['Me','V','E','Ma','J','S','U','N']}
ss = pd.DataFrame(ss_names) 
ss['m'] = [0.0553, 0.815, 1.00, 0.107, 317.83, 95.159, 14.536, 17.147]
ss['r'] = [0.383,0.950,1.0, 0.532, 10.973, 9.140, 3.981, 3.865]
ss['a'] = [0.387, 0.723 , 1.0, 1.524, 5.204, 9.582, 19.201, 30.047]
ss['rho'] = (ss.m * mearth)/(4./3 * np.pi * (ss.r * rearth)**3.)
ss['flux'] = 1./ss.a**2
ss['per'] = 365.25 * pow(ss.a, 3./2)
ss = ss.set_index('name')
ss.head()
# Out:
#              m       r      a       rho      flux          per
# name
# Me      0.0553   0.383  0.387  5.435851  6.676949    87.933968
# V       0.8150   0.950  0.723  5.249592  1.913037   224.542043
# E       1.0000   1.000  1.000  5.522539  1.000000   365.250000
# Ma      0.1070   0.532  1.524  3.924530  0.430556   687.175513
# J     317.8300  10.973  5.204  1.328488  0.036925  4336.068720

# %%
#df.set_index(n.rstrip for n in df.index)
df.index
# Out:
# Index([u'55 Cnc e', u'CoRoT-1 b', u'CoRoT-10 b', u'CoRoT-11 b', u'CoRoT-12 b', u'CoRoT-13 b', u'CoRoT-14 b', u'CoRoT-16 b', u'CoRoT-17 b', u'CoRoT-18 b', u'CoRoT-19 b', u'CoRoT-2 b', u'CoRoT-23 b', u'CoRoT-3 b', u'CoRoT-4 b', u'CoRoT-5 b', u'CoRoT-6 b', u'CoRoT-7 b', u'CoRoT-8 b', u'CoRoT-9 b', u'Fomalhaut b', u'GJ 1214 b', u'GJ 3470 b', u'GJ 436 b', u'HAT-P-1 b', u'HAT-P-11 b', u'HAT-P-12 b', u'HAT-P-13 b', u'HAT-P-14 b', u'HAT-P-15 b', u'HAT-P-16 b', u'HAT-P-17 b', u'HAT-P-18 b', u'HAT-P-19 b', u'HAT-P-2 b', u'HAT-P-20 b', u'HAT-P-21 b', u'HAT-P-22 b', u'HAT-P-23 b', u'HAT-P-24 b', u'HAT-P-25 b', u'HAT-P-26 b', u'HAT-P-27 b', u'HAT-P-28 b', u'HAT-P-29 b', u'HAT-P-3 b', u'HAT-P-30 b', u'HAT-P-31 b', u'HAT-P-32 b', u'HAT-P-33 b', u'HAT-P-34 b', u'HAT-P-35 b', u'HAT-P-36 b', u'HAT-P-37 b', u'HAT-P-38 b', u'HAT-P-39 b', u'HAT-P-4 b', u'HAT-P-40 b', u'HAT-P-41 b', u'HAT-P-5 b', u'HAT-P-6 b', u'HAT-P-7 b', u'HAT-P-8 b', u'HAT-P-9 b', u'HATS-1 b', u'HATS-2 b', u'HD 149026 b', u'HD 17156 b', u'HD 189733 b', u'HD 209458 b', u'HD 80606 b', u'HD 97658 b', u'HR 8799 b', u'HR 8799 c', u'HR 8799 d', u'KELT-2 A b', u'KELT-3 b', u'KOI-200 b', u'KOI-889 b', u'Kepler-10 b', u'Kepler-11 b', u'Kepler-11 c', u'Kepler-11 d', u'Kepler-11 e', u'Kepler-11 f', u'Kepler-12 b', u'Kepler-14 b', u'Kepler-15 b', u'Kepler-16 b', u'Kepler-17 b', u'Kepler-18 b', u'Kepler-18 c', u'Kepler-18 d', u'Kepler-20 b', u'Kepler-20 c', u'Kepler-20 d', u'Kepler-30 b', u'Kepler-30 c', u'Kepler-30 d', u'Kepler-34 b', u'Kepler-35 b', u'Kepler-36 b', u'Kepler-36 c', u'Kepler-39 b', u'Kepler-4 b', u'Kepler-40 b', u'Kepler-41 b', u'Kepler-43 b', u'Kepler-44 b', u'Kepler-45 b', u'Kepler-5 b', u'Kepler-6 b', u'Kepler-68 b', u'Kepler-68 c', u'Kepler-7 b', u'Kepler-77 b', u'Kepler-8 b', u'Kepler-9 b', u'Kepler-9 c', u'OGLE-TR-10 b', u'OGLE-TR-111 b', u'OGLE-TR-113 b', u'OGLE-TR-132 b', u'OGLE-TR-182 b', u'OGLE-TR-211 b', u'OGLE-TR-56 b', u'OGLE2-TR-L9 b', u'Qatar-1 b', u'Qatar-2 b', u'TrES-1 b', u'TrES-2 b', u'TrES-3 b', u'TrES-4 b', u'TrES-5 b', u'WASP-1 b', u'WASP-10 b', u'WASP-11 b', u'WASP-12 b', u'WASP-13 b', u'WASP-14 b', u'WASP-15 b', u'WASP-16 b', u'WASP-17 b', u'WASP-18 b', u'WASP-19 b', u'WASP-2 b', u'WASP-21 b', u'WASP-22 b', u'WASP-23 b', u'WASP-24 b', u'WASP-25 b', u'WASP-26 b', u'WASP-29 b', u'WASP-3 b', u'WASP-31 b', u'WASP-32 b', u'WASP-34 b', u'WASP-35 b', u'WASP-36 b', u'WASP-37 b', u'WASP-38 b', u'WASP-39 b', u'WASP-4 b', u'WASP-41 b', u'WASP-42 b', u'WASP-43 b', u'WASP-44 b', u'WASP-45 b', u'WASP-46 b', u'WASP-47 b', u'WASP-48 b', u'WASP-49 b', u'WASP-5 b', u'WASP-50 b', u'WASP-52 b', u'WASP-54 b', u'WASP-55 b', u'WASP-56 b', u'WASP-57 b', u'WASP-58 b', u'WASP-59 b', u'WASP-6 b', u'WASP-61 b', u'WASP-62 b', u'WASP-63 b', u'WASP-64 b', u'WASP-66 b', u'WASP-67 b', u'WASP-7 b', u'WASP-72 b', u'WASP-77 A b', u'WASP-78 b', u'WASP-79 b', u'WASP-8 b', u'WASP-80 b', u'XO-1 b', u'XO-2 b', u'XO-3 b', u'XO-4 b', u'XO-5 b', u'KOI-41.01', u'KOI-41.02', u'KOI-41.03', u'KOI-69.01', u'KOI-82.01', u'KOI-82.02', u'KOI-82.03', u'KOI-82.04', u'KOI-82.05', u'KOI-104.01', u'KOI-108.01', u'KOI-108.02', u'KOI-116.01', u'KOI-116.02', u'KOI-116.03', u'KOI-116.04', u'KOI-122.01', u'KOI-123.01', u'KOI-123.02', u'KOI-148.01', u'KOI-148.02', u'KOI-148.03', u'KOI-153.01', u'KOI-153.02', u'KOI-244.01', u'KOI-244.02', u'KOI-245.01', u'KOI-245.02', u'KOI-245.03', u'KOI-246.01', u'KOI-246.02', u'KOI-261.01', u'KOI-283.01', u'KOI-283.02', u'KOI-292.01', u'KOI-299.01', u'KOI-305.01', u'KOI-321.01', u'KOI-321.02', u'KOI-1442.01', u'KOI-1612.01', u'KOI-1925.01', u'Kepler-78 b', u'KOI-94 b', u'KOI-94 c', u'KOI-94 d', u'KOI-94 e', u'KOI-152 b', u'KOI-152 c', u'KOI-152 d', u'KOI-152 e', u'KOI-314 b', u'KOI-314 c'], dtype=object)

# %%
sp = df[df.r <= 4.]
sp.sort(inplace=True)
sp.loc[['KOI-152 b','KOI-152 c','KOI-152 e','KOI-314 b','KOI-314 c'],['per','m','um','r','ur','a','flux','firstref','orbref']]
# Out:
#                 per      m    um     r    ur         a        flux  \
# KOI-152 b  13.48450  10.90  6.70  3.47  0.07  0.117000  161.456472
# KOI-152 c  27.40290   5.90  2.10  3.72  0.08  0.187000   63.225260
# KOI-152 e  81.06590   4.10  1.15  3.49  0.14  0.386000   14.833204
# KOI-314 b  13.78164   3.83  1.37  1.61  0.16  0.112499    4.641660
# KOI-314 c  23.08933   1.01  0.38  1.61  0.16  0.158689    2.332788
#
#                firstref          orbref
# KOI-152 b  Borucki 2011  Lissauer 2013b
# KOI-152 c  Borucki 2011  Lissauer 2013b
# KOI-152 e  Borucki 2013  Lissauer 2013b
# KOI-314 b  Borucki 2011    Kipping 2014
# KOI-314 c  Borucki 2011    Kipping 2014

# %%
df.to_csv('exoplanet_table_full.csv')
df.to_pickle('exoplanets.pickle')
sp_cut = sp.ix[:,['m','um','r','ur','rho','urho','firstref','orbref']]
sp_cut.to_csv('small_exoplanets.csv')
sp.to_pickle('small_exoplanets.pickle')

# %%
len(sp)
# Out:
# 65

# %%
print sp.rho[30:]
# Out:
# name
# KOI-261.01      2.260
# KOI-283.01      6.000
# KOI-283.02     77.700
# KOI-292.01      5.440
# KOI-299.01      2.180
# KOI-305.01     10.900
# KOI-314 b       5.000
# KOI-314 c       1.310
# KOI-321.01      9.200
# KOI-321.02     13.800
# KOI-41.01       0.350
# KOI-41.02      14.250
# KOI-41.03      -5.720
# KOI-69.01       4.170
# KOI-82.01       4.680
# KOI-82.02      13.270
# KOI-82.03       4.920
# KOI-82.04     -44.240
# KOI-82.05      23.290
# KOI-94 b       10.100
# Kepler-10 b     8.150
# Kepler-11 b     1.720
# Kepler-11 c     0.660
# Kepler-11 d     1.280
# Kepler-11 f     0.690
# Kepler-18 b     4.900
# Kepler-20 b     6.500
# Kepler-20 c     2.910
# Kepler-20 d     2.035
# Kepler-30 b     1.020
# Kepler-36 b     7.460
# Kepler-36 c     0.890
# Kepler-68 b     3.320
# Kepler-68 c    28.000
# Kepler-78 b     5.300
# Name: rho, dtype: float64
